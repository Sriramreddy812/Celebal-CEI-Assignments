# %% [markdown]
# # 🧠 Single Agent Pipeline Project
#
# ## Problem Statement
# Build a **Single-Agent Smart Assistant** that:
# - Understands user queries
# - Routes tasks based on intent
# - Uses tools when required
# - Returns structured JSON output
#
# ### The agent should handle:
# - Math queries → Calculator Tool
# - Keyword extraction → Keyword Tool
# - General queries → Direct response
#
# ---
# ### 🛠️ What You Need to Implement
# - Agent logic
# - Conditional routing
# - Tool integration
# - Basic error handling
#
# ### 🚀 Bonus
# - Improve routing
# - Add logging
# - Add more tools

# %%
# 🛠️ TOOL 1: Calculator

def calculator(expression: str) -> str:
    """Evaluate a mathematical expression."""
    try:
        return str(eval(expression))
    except Exception:
        return "Error in calculation"

# %%
# 🛠️ TOOL 2: Keyword Extractor

def extract_keywords(text: str) -> list:
    """Extract keywords from text."""
    try:
        words = text.split()
        keywords = list(set([w.lower() for w in words if len(w) > 4]))
        return keywords[:5]
    except Exception:
        return []

# %% [markdown]
# ## 🤖 Implement Agent Logic Below
#
# 👉 Use conditional routing:
# - If query contains "calculate" → use calculator
# - If query contains "keywords" → use keyword extractor
# - Else → general response

# %%
from datetime import datetime
import logging

def agent(query: str):
    query_lower = query.lower()
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    try:
        logging.info(f"User Query: {query}")

        if "calculate" in query_lower:
            expression = query_lower.replace("calculate", "").strip()
            return {
                "type": "calculation",
                "result": calculator(expression),
                "timestamp": timestamp
            }

        elif "keywords" in query_lower:
            text = query.replace("Extract keywords from", "").replace(
                "extract keywords from", ""
            ).replace("keywords", "").strip()

            return {
                "type": "keywords",
                "result": extract_keywords(text),
                "timestamp": timestamp
            }

        elif "count words" in query_lower:
            text = query.replace("Count words in", "").replace(
                "count words in", ""
            ).strip()

            return {
                "type": "word_count",
                "result": word_count(text),
                "timestamp": timestamp
            }

        else:
            return {
                "type": "general",
                "result": "I can help with calculations, keyword extraction, or word counting.",
                "timestamp": timestamp
            }

    except Exception as e:
        logging.error(f"Error: {e}")
        return {
            "type": "error",
            "result": str(e),
            "timestamp": timestamp
        }

# %% [markdown]
# ## 📦 Expected Output Format
#
# ```
# {
#   "type": "calculation / keywords / general / error",
#   "result": ...
# }
# ```

# %%
# 🧪 Test Cases

queries = [
    "Calculate 20 + 5",
    "Extract keywords from Artificial Intelligence is transforming industries",
    "What is machine learning?",
    "Calculate 100 / 4",
    "Extract keywords from Python is widely used in Data Science and Machine Learning"
]

for q in queries:
    print("Query:", q)
    print("Response:", agent(q))
    print("-" * 50)
# Out:
# Query: Calculate 20 + 5
# Response: {'type': 'calculation', 'result': '25'}
# --------------------------------------------------
# Query: Extract keywords from Artificial Intelligence is transforming industries
# Response: {'type': 'keywords', 'result': ['artificial', 'transforming', 'intelligence', 'industries']}
# --------------------------------------------------
# Query: What is machine learning?
# Response: {'type': 'general', 'result': 'I can help with calculations, keyword extraction, or word counting.'}
# --------------------------------------------------
# Query: Calculate 100 / 4
# Response: {'type': 'calculation', 'result': '25.0'}
# --------------------------------------------------
# Query: Extract keywords from Python is widely used in Data Science and Machine Learning
# Response: {'type': 'keywords', 'result': ['machine', 'science', 'learning', 'python', 'widely']}
# --------------------------------------------------

# %%
# 🎯 Interactive Mode

while True:
    user_input = input("Enter query (type 'exit' to stop): ")
    if user_input.lower() == "exit":
        break
    print("Response:", agent(user_input))
# Out:
# Enter query (type 'exit' to stop): Calculate 45+8
# Response: {'type': 'calculation', 'result': '53', 'timestamp': '2026-07-18 17:16:48'}
# Enter query (type 'exit' to stop): Extract keywords from formula 1
# Response: {'type': 'keywords', 'result': ['formula'], 'timestamp': '2026-07-18 17:17:10'}
# Enter query (type 'exit' to stop): Extract keywords from Cricket is widely played in India and is one of the most popular sports in the world.
# Response: {'type': 'keywords', 'result': ['india', 'popular', 'world.', 'played', 'widely'], 'timestamp': '2026-07-18 17:17:50'}
# Enter query (type 'exit' to stop): exit

# %% [markdown]
# ## ⭐ Bonus Task 1: Agent Logging
#
# This bonus task records every user query processed by the agent into a log file. Logging helps in debugging, monitoring, and analyzing agent behavior.

# %%
import logging

logging.basicConfig(
    filename="agent.log",
    level=logging.INFO,
    format="%(asctime)s - %(message)s"
)

logging.info("Agent logging initialized.")

print("Logging has been enabled. Logs will be saved to agent.log")
# Out:
# Logging has been enabled. Logs will be saved to agent.log

# %% [markdown]
# ## ⭐ Bonus Task 2: Word Count Tool
#
# This bonus task adds a new tool that counts the number of words in a given sentence. It demonstrates how an agent can be extended by adding additional tools.

# %%
def word_count(text):
    return len(text.split())

# %%
print(agent("Count words in Artificial Intelligence is changing the world"))
# Out:
# {'type': 'word_count', 'result': 6, 'timestamp': '2026-07-18 17:16:18'}

# %% [markdown]
# ## ⭐ Bonus Task 3: Add Timestamp to Responses
#
# This bonus task adds the current time to every agent response. It helps track when a query was processed by the agent.

# %%
from datetime import datetime

# %%
# ⭐ Bonus Task 3: Comprehensive Agent Testing

bonus_queries = [
    "Calculate 45 + 55",
    "Calculate 100 / 20",
    "Extract keywords from Machine Learning is a subset of Artificial Intelligence",
    "Count words in Python is easy to learn",
    "Hello Agent"
]

print("===== BONUS TASK 3 OUTPUT =====\n")

for query in bonus_queries:
    print("Query:", query)
    print("Response:", agent(query))
    print("-" * 50)
# Out:
# ===== BONUS TASK 3 OUTPUT =====
#
# Query: Calculate 45 + 55
# Response: {'type': 'calculation', 'result': '100', 'timestamp': '2026-07-18 17:16:23'}
# --------------------------------------------------
# Query: Calculate 100 / 20
# Response: {'type': 'calculation', 'result': '5.0', 'timestamp': '2026-07-18 17:16:23'}
# --------------------------------------------------
# Query: Extract keywords from Machine Learning is a subset of Artificial Intelligence
# Response: {'type': 'keywords', 'result': ['subset', 'machine', 'artificial', 'intelligence', 'learning'], 'timestamp': '2026-07-18 17:16:23'}
# --------------------------------------------------
# Query: Count words in Python is easy to learn
# Response: {'type': 'word_count', 'result': 5, 'timestamp': '2026-07-18 17:16:23'}
# --------------------------------------------------
# Query: Hello Agent
# ...
